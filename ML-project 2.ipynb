# %%
! git init
# Out:
# Initialized empty Git repository in C:/Users/banda/Downloads/ML- project 2/.git/

# %%
! git add .

# %%
# !git commit -m "IML project Jupyter Notebooks"
# Out:
# [master (root-commit) 5291df2] IML project Jupyter Notebooks
#  2 files changed, 29 insertions(+)
#  create mode 100644 .ipynb_checkpoints/Untitled-checkpoint.ipynb
#  create mode 100644 Untitled.ipynb

# %%
# !git push -u origin master
# Out:
# fatal: 'origin' does not appear to be a git repository
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.

# %%
conda create venv
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 get_ipython().run_line_magic('conda', 'create venv ')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\packaging.py:30, in is_conda_environment.<locals>.wrapper(*args, **kwargs)
# ...

# %%
# !git push -u origin main
# Out:
# error: src refspec main does not match any
# error: failed to push some refs to 'origin'

# %%
! git add .

# %%
# !git commit -m "ML project 2 Jupyter Notebooks"
# Out:
# [master 3f0d825] ML project 2 Jupyter Notebooks
#  3 files changed, 148 insertions(+), 23 deletions(-)
#  rename .ipynb_checkpoints/{Untitled-checkpoint.ipynb => ML-project 2-checkpoint.ipynb} (100%)
#  create mode 100644 ML-project 2.ipynb
#  delete mode 100644 Untitled.ipynb

# %%
! git branch -m main

# %%
# !git remote add origin https://github.com/pavankalyan998/ML-Project-2.git

# %%
! git push -u origin main
# Out:
# branch 'main' set up to track 'origin/main'.
# To https://github.com/pavankalyan998/ML-Project-2.git
#  * [new branch]      main -> main
