# %%
## END to END ML Project - 2

# %%
# !git add .

# %%
! git add Readme
# Out:
# fatal: pathspec 'Readme' did not match any files

# %%
! git add README
# Out:
# fatal: pathspec 'README' did not match any files

# %%
! git commit -m "project start"
# Out:
# [main 5d5d83b] project start
#  3 files changed, 245 insertions(+), 1 deletion(-)
#  create mode 100644 .ipynb_checkpoints/Readme-checkpoint.ipynb
#  create mode 100644 Readme.ipynb

# %%
! git branch -m main

# %%
! git remote add origin https://github.com/pavankalyan998/ML-Project-2
# Out:
# error: remote origin already exists.

# %%
! git push -u origin main
# Out:
# To https://github.com/pavankalyan998/ML-Project-2.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/pavankalyan998/ML-Project-2.git'
# hint: Updates were rejected because the remote contains work that you do not
# hint: have locally. This is usually caused by another repository pushing to
# hint: the same ref. If you want to integrate the remote changes, use
# hint: 'git pull' before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
! git pull
# Out:
# CONFLICT (modify/delete): ML-project 2.ipynb deleted in 7a3731bff0a02b464acd891bc7d465573c38066c and modified in HEAD.  Version HEAD of ML-project 2.ipynb left in tree.
# From https://github.com/pavankalyan998/ML-Project-2
#    3f0d825..7a3731b  main       -> origin/main
# ...
# Automatic merge failed; fix conflicts and then commit the result.
